# %%
import pandas as pd

# %%
df = pd.read_csv('Data_science_jobs.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0  Founded              Size   Location Type of Ownership  \
# 0           0   1967.0  10000+ Employees  Bangalore  Company - Public
# 1           1   1967.0  10000+ Employees  Hyderābād  Company - Public
# 2           2   1967.0  10000+ Employees       Pune  Company - Public
# 3           3   1967.0  10000+ Employees     Remote  Company - Public
# 4           4   1967.0  10000+ Employees  Bangalore  Company - Public
#
#           Sector             Revenue  Rating Salary Estimate  \
# 0  Manufacturing  $10+ billion (USD)     4.0             NaN
# 1  Manufacturing  $10+ billion (USD)     4.0             NaN
# 2  Manufacturing  $10+ billion (USD)     4.0             NaN
# 3  Manufacturing  $10+ billion (USD)     4.0             NaN
# 4  Manufacturing  $10+ billion (USD)     4.0             NaN
#
#                  Job Title                                    Job Description  \
# 0           Data Scientist  Job Expectations\nThe Data Scientist job expec...
# 1  Product: Data Scientist  Job Expectations\nThe Data Scientist job expec...
# 2         Data Scientist I  Job Expectations\nThe Data Scientist job expec...
# 3    Senior Data Scientist  Job Expectations\nThe Data Scientist job expec...
# 4           Data Scientist  Job Expectations\nThe Data Scientist job expec...
#
#                                 Industry                     Company Name
# 0  Electrical & Electronic Manufacturing           Applied Materials Inc.
# 1  Electrical & Electronic Manufacturing                           Indeed
# 2  Electrical & Electronic Manufacturing                       UST Global
# 3  Electrical & Electronic Manufacturing  ParallelDots Technology Pvt Ltd
# 4  Electrical & Electronic Manufacturing                             Visa

# %%
df = df.drop(['Unnamed: 0'],axis=1)

# %%
#df = df.drop(df.index[:30],axis=0)

# %%
df.head(5)
# Out:
#    Founded              Size   Location Type of Ownership         Sector  \
# 0   1967.0  10000+ Employees  Bangalore  Company - Public  Manufacturing
# 1   1967.0  10000+ Employees  Hyderābād  Company - Public  Manufacturing
# 2   1967.0  10000+ Employees       Pune  Company - Public  Manufacturing
# 3   1967.0  10000+ Employees     Remote  Company - Public  Manufacturing
# 4   1967.0  10000+ Employees  Bangalore  Company - Public  Manufacturing
#
#               Revenue  Rating Salary Estimate                Job Title  \
# 0  $10+ billion (USD)     4.0             NaN           Data Scientist
# 1  $10+ billion (USD)     4.0             NaN  Product: Data Scientist
# 2  $10+ billion (USD)     4.0             NaN         Data Scientist I
# 3  $10+ billion (USD)     4.0             NaN    Senior Data Scientist
# 4  $10+ billion (USD)     4.0             NaN           Data Scientist
#
#                                      Job Description  \
# 0  Job Expectations\nThe Data Scientist job expec...
# 1  Job Expectations\nThe Data Scientist job expec...
# 2  Job Expectations\nThe Data Scientist job expec...
# 3  Job Expectations\nThe Data Scientist job expec...
# 4  Job Expectations\nThe Data Scientist job expec...
#
#                                 Industry                     Company Name
# 0  Electrical & Electronic Manufacturing           Applied Materials Inc.
# 1  Electrical & Electronic Manufacturing                           Indeed
# 2  Electrical & Electronic Manufacturing                       UST Global
# 3  Electrical & Electronic Manufacturing  ParallelDots Technology Pvt Ltd
# 4  Electrical & Electronic Manufacturing                             Visa

# %%
df = df.drop(df.index[0:30])

# %%
df.reset_index()
# Out:
#      index  Founded Size   Location Type of Ownership Sector Revenue  Rating  \
# 0       30      NaN  NaN       Pune               NaN    NaN     NaN     NaN
# 1       31      NaN  NaN       Pune               NaN    NaN     NaN     NaN
# 2       32      NaN  NaN     Mumbai               NaN    NaN     NaN     NaN
# 3       33      NaN  NaN       Pune               NaN    NaN     NaN     NaN
# 4       34      NaN  NaN       Pune               NaN    NaN     NaN     NaN
# ..     ...      ...  ...        ...               ...    ...     ...     ...
# 145    175      NaN  NaN  Bangalore               NaN    NaN     NaN     NaN
# 146    176      NaN  NaN  Bangalore               NaN    NaN     NaN     NaN
# 147    177      NaN  NaN  Bangalore               NaN    NaN     NaN     NaN
# 148    178      NaN  NaN  Bangalore               NaN    NaN     NaN     NaN
# 149    179      NaN  NaN  Bangalore               NaN    NaN     NaN     NaN
#
#                  Salary Estimate  \
# 0          ₹223K (Employer est.)
# 1          ₹223K (Employer est.)
# 2          ₹223K (Employer est.)
# 3          ₹223K (Employer est.)
# 4          ₹223K (Employer est.)
# ..                           ...
# 145  ₹500K - ₹1M (Employer est.)
# 146  ₹500K - ₹1M (Employer est.)
# 147  ₹500K - ₹1M (Employer est.)
# 148  ₹500K - ₹1M (Employer est.)
# 149  ₹500K - ₹1M (Employer est.)
#
#                                              Job Title  \
# 0                                       Data Scientist
# 1                             Associate Data Scientist
# 2        Data Scientist Associate - Wholesale Payments
# 3                                       Data Scientist
# 4                            Specialist Data Scientist
# ..                                                 ...
# 145                     ENGINEER - AI/MACHINE-LEARNING
# 146                     Data Scientist II - APAC-based
# 147                                     Data Scientist
# 148                                     Data Scientist
# 149  Artificial Intelligence & Machine Learning Exp...
#
#                                        Job Description Industry  \
# 0    Responsibilities for Data Scientist/ NLP Engin...      NaN
# 1    Responsibilities for Data Scientist/ NLP Engin...      NaN
# 2    Responsibilities for Data Scientist/ NLP Engin...      NaN
# 3    Responsibilities for Data Scientist/ NLP Engin...      NaN
# 4    Responsibilities for Data Scientist/ NLP Engin...      NaN
# ..                                                 ...      ...
# 145  Experience: 2 - 4 years\nSkills Required:\nMac...      NaN
# 146  Experience: 2 - 4 years\nSkills Required:\nMac...      NaN
# 147  Experience: 2 - 4 years\nSkills Required:\nMac...      NaN
# 148  Experience: 2 - 4 years\nSkills Required:\nMac...      NaN
# 149  Experience: 2 - 4 years\nSkills Required:\nMac...      NaN
#
#                   Company Name
# 0                   UTURNGROUP
# 1            Yash Technologies
# 2    JPMorgan Chase Bank, N.A.
# 3       KPIT Technologies GmbH
# 4                         NICE
# ..                         ...
# 145       Harman International
# 146                    Agiloft
# 147                     Skoruz
# 148               Polaris Inc.
# 149            Infosys Limited
#
# [150 rows x 13 columns]

# %%
df = df.reset_index()

# %%
df.head(5)
# Out:
#    index  Founded Size Location Type of Ownership Sector Revenue  Rating  \
# 0     30      NaN  NaN     Pune               NaN    NaN     NaN     NaN
# 1     31      NaN  NaN     Pune               NaN    NaN     NaN     NaN
# 2     32      NaN  NaN   Mumbai               NaN    NaN     NaN     NaN
# 3     33      NaN  NaN     Pune               NaN    NaN     NaN     NaN
# 4     34      NaN  NaN     Pune               NaN    NaN     NaN     NaN
#
#          Salary Estimate                                      Job Title  \
# 0  ₹223K (Employer est.)                                 Data Scientist
# 1  ₹223K (Employer est.)                       Associate Data Scientist
# 2  ₹223K (Employer est.)  Data Scientist Associate - Wholesale Payments
# 3  ₹223K (Employer est.)                                 Data Scientist
# 4  ₹223K (Employer est.)                      Specialist Data Scientist
#
#                                      Job Description Industry  \
# 0  Responsibilities for Data Scientist/ NLP Engin...      NaN
# 1  Responsibilities for Data Scientist/ NLP Engin...      NaN
# 2  Responsibilities for Data Scientist/ NLP Engin...      NaN
# 3  Responsibilities for Data Scientist/ NLP Engin...      NaN
# 4  Responsibilities for Data Scientist/ NLP Engin...      NaN
#
#                 Company Name
# 0                 UTURNGROUP
# 1          Yash Technologies
# 2  JPMorgan Chase Bank, N.A.
# 3     KPIT Technologies GmbH
# 4                       NICE

# %%
df = df.drop(['index'],axis=1)

# %%
df.head(5)
# Out:
#    Founded Size Location Type of Ownership Sector Revenue  Rating  \
# 0      NaN  NaN     Pune               NaN    NaN     NaN     NaN
# 1      NaN  NaN     Pune               NaN    NaN     NaN     NaN
# 2      NaN  NaN   Mumbai               NaN    NaN     NaN     NaN
# 3      NaN  NaN     Pune               NaN    NaN     NaN     NaN
# 4      NaN  NaN     Pune               NaN    NaN     NaN     NaN
#
#          Salary Estimate                                      Job Title  \
# 0  ₹223K (Employer est.)                                 Data Scientist
# 1  ₹223K (Employer est.)                       Associate Data Scientist
# 2  ₹223K (Employer est.)  Data Scientist Associate - Wholesale Payments
# 3  ₹223K (Employer est.)                                 Data Scientist
# 4  ₹223K (Employer est.)                      Specialist Data Scientist
#
#                                      Job Description Industry  \
# 0  Responsibilities for Data Scientist/ NLP Engin...      NaN
# 1  Responsibilities for Data Scientist/ NLP Engin...      NaN
# 2  Responsibilities for Data Scientist/ NLP Engin...      NaN
# 3  Responsibilities for Data Scientist/ NLP Engin...      NaN
# 4  Responsibilities for Data Scientist/ NLP Engin...      NaN
#
#                 Company Name
# 0                 UTURNGROUP
# 1          Yash Technologies
# 2  JPMorgan Chase Bank, N.A.
# 3     KPIT Technologies GmbH
# 4                       NICE

# %%
df.drop(['Founded','Size','Type of Ownership','Sector','Rating','Industry'],axis=1,inplace=True)

# %%
df = df[['Company Name','Job Title','Job Description','Salary Estimate','Location','Revenue']]

# %%
df.head(5)
# Out:
#                 Company Name                                      Job Title  \
# 0                 UTURNGROUP                                 Data Scientist
# 1          Yash Technologies                       Associate Data Scientist
# 2  JPMorgan Chase Bank, N.A.  Data Scientist Associate - Wholesale Payments
# 3     KPIT Technologies GmbH                                 Data Scientist
# 4                       NICE                      Specialist Data Scientist
#
#                                      Job Description        Salary Estimate  \
# 0  Responsibilities for Data Scientist/ NLP Engin...  ₹223K (Employer est.)
# 1  Responsibilities for Data Scientist/ NLP Engin...  ₹223K (Employer est.)
# 2  Responsibilities for Data Scientist/ NLP Engin...  ₹223K (Employer est.)
# 3  Responsibilities for Data Scientist/ NLP Engin...  ₹223K (Employer est.)
# 4  Responsibilities for Data Scientist/ NLP Engin...  ₹223K (Employer est.)
#
#   Location Revenue
# 0     Pune     NaN
# 1     Pune     NaN
# 2   Mumbai     NaN
# 3     Pune     NaN
# 4     Pune     NaN

# %%
# removing text from salary

# %%
salary = df['Salary Estimate'].apply(lambda x: x.split('(')[0] )

# %%
#removing ₹ and K from salary

# %%
salary = salary.apply(lambda x: x.replace('₹','').replace('K',''))
salary = salary.apply(lambda x: x.replace('1M','1000'))

# %%
salary.head(5)
# Out:
# 0    223
# 1    223
# 2    223
# 3    223
# 4    223
# Name: Salary Estimate, dtype: object

# %%
# getting min_salary and max_salary

# %%
salary = salary.apply(lambda x:x.replace(' ',''))

# %%
df['min_salary'] = salary.apply(lambda x:int(x.split('-')[0]))
df['max_salary'] = salary.apply(lambda x:int(x.split('-')[-1]))
# Out:
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\users\dell\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.head(5)
# Out:
#                 Company Name                                      Job Title  \
# 0                 UTURNGROUP                                 Data Scientist
# 1          Yash Technologies                       Associate Data Scientist
# 2  JPMorgan Chase Bank, N.A.  Data Scientist Associate - Wholesale Payments
# 3     KPIT Technologies GmbH                                 Data Scientist
# 4                       NICE                      Specialist Data Scientist
#
#                                      Job Description        Salary Estimate  \
# 0  Responsibilities for Data Scientist/ NLP Engin...  ₹223K (Employer est.)
# 1  Responsibilities for Data Scientist/ NLP Engin...  ₹223K (Employer est.)
# 2  Responsibilities for Data Scientist/ NLP Engin...  ₹223K (Employer est.)
# 3  Responsibilities for Data Scientist/ NLP Engin...  ₹223K (Employer est.)
# 4  Responsibilities for Data Scientist/ NLP Engin...  ₹223K (Employer est.)
#
#   Location Revenue  min_salary  max_salary
# 0     Pune     NaN         223         223
# 1     Pune     NaN         223         223
# 2   Mumbai     NaN         223         223
# 3     Pune     NaN         223         223
# 4     Pune     NaN         223         223

# %%
df.tail(5)
# Out:
#              Company Name                                          Job Title  \
# 145  Harman International                     ENGINEER - AI/MACHINE-LEARNING
# 146               Agiloft                     Data Scientist II - APAC-based
# 147                Skoruz                                     Data Scientist
# 148          Polaris Inc.                                     Data Scientist
# 149       Infosys Limited  Artificial Intelligence & Machine Learning Exp...
#
#                                        Job Description  \
# 145  Experience: 2 - 4 years\nSkills Required:\nMac...
# 146  Experience: 2 - 4 years\nSkills Required:\nMac...
# 147  Experience: 2 - 4 years\nSkills Required:\nMac...
# 148  Experience: 2 - 4 years\nSkills Required:\nMac...
# 149  Experience: 2 - 4 years\nSkills Required:\nMac...
#
#                  Salary Estimate   Location Revenue  min_salary  max_salary
# 145  ₹500K - ₹1M (Employer est.)  Bangalore     NaN         500        1000
# 146  ₹500K - ₹1M (Employer est.)  Bangalore     NaN         500        1000
# 147  ₹500K - ₹1M (Employer est.)  Bangalore     NaN         500        1000
# 148  ₹500K - ₹1M (Employer est.)  Bangalore     NaN         500        1000
# 149  ₹500K - ₹1M (Employer est.)  Bangalore     NaN         500        1000
