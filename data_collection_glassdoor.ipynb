# %%
from selenium import webdriver
import time
import pandas as pd
import numpy as np

# %%
def get_jobs(requiredJobData,  noOfPages, requiredCountryData = " "):
    # Initializing the chrome browser
    driver = webdriver.Chrome(executable_path='D:/projects/jupyter/chromedriver')


    # Opening the URL
    url = "https://www.glassdoor.com/Job/jobs.htm?suggestCount=0&suggestChosen=false&clickSource=searchBtn&typedKeyword="+requiredJobData+"&sc.keyword="+requiredJobData+"&locT=&locId=&jobType="
    driver.get(url)
    
    # Maximizing the opened window
    driver.maximize_window()
    
    # Adding implicit wait
    driver.set_page_load_timeout(30)
    
    # Entering city (or) state (or) country name
    if requiredCountryData == " ":
        driver.find_element_by_id("sc.location").clear()
        driver.find_element_by_xpath("//form[@id='scBar']//button[contains(@class, 'gd-ui-button')]").click()
        
    else:
        driver.find_element_by_id("sc.location").send_keys(requiredCountryData)
        driver.find_element_by_xpath("//form[@id='scBar']//button[contains(@class, 'gd-ui-button')]").click()

    time.sleep(3)

    # To get the Popup
    toGetPopUp = []
    toGetPopUp = driver.find_elements_by_xpath("//*[contains(@class,'react-job-listing')]")    
    toGetPopUp[0].click()

    time.sleep(2)

    # To close the popup
    closeButton = driver.find_element_by_xpath("//*[contains(@class, 'modal_closeIcon-svg')]")
    closeButton.click()

    # Creating a Dataframe to store the data in it.
    data = pd.DataFrame(columns={'Job Title','Salary Estimate', 'Job Description', 'Rating', 'Company Name', 'Location', 'Size', 'Founded', 'Type of Ownership', 'Industry', 'Sector', 'Revenue'})

    # This loop is to get required code from the webpage.

    # Adding implicit wait
    driver.set_page_load_timeout(30)

    # To get required number of pages of job data.
    for page in range(noOfPages):
        
        # Time for every page to wait
        driver.set_page_load_timeout(30)

        # Multiple values are taken.
        jobTitles = driver.find_elements_by_xpath("//li[contains(@class, 'react-job-listing')]//a[contains(@class, 'jobLink css-1rd3saf eigr9kq2')]//span")
        companyNames = driver.find_elements_by_xpath("//li[contains(@class, 'react-job-listing')]//a[@class=' css-l2wjgv e1n63ojh0 jobLink']")
        jobLocations = driver.find_elements_by_xpath("//div[contains(@class, 'd-flex flex-wrap css-11d3uq0 e1rrn5ka2')]/span")

        # Locating all the listed jobs
        allJobs = driver.find_elements_by_xpath("//ul[@data-test='jlGrid']//li")

        for i in range(len(allJobs)):

            try:
                jobDescriptionText = driver.find_element_by_xpath("//div[contains(@class,'jobDescriptionContent')]").text
            except Exception:
                jobDescriptionText = np.nan

            try:
                jobRatingText = driver.find_element_by_xpath("//span[contains(@class,'css-1m5m32b e1tk4kwz2')]").text
            except Exception:
                jobRatingText = np.nan

            try:
                emplooyeSizeText = driver.find_element_by_xpath("//div[@id='CompanyContainer']//div[@class='d-flex flex-wrap']/div[1]/span[@class='css-i9gxme e1pvx6aw2']").text
            except Exception:
                emplooyeSizeText = np.nan

            try:
                companyFoundedText = driver.find_element_by_xpath("//div[@id='CompanyContainer']//div[@class='d-flex flex-wrap']/div[2]/span[@class='css-i9gxme e1pvx6aw2']").text
            except Exception:
                companyFoundedText = np.nan

            try:
                companyTypeText = driver.find_element_by_xpath("//div[@id='CompanyContainer']//div[@class='d-flex flex-wrap']/div[3]/span[@class='css-i9gxme e1pvx6aw2']").text
            except Exception:
                companyTypeText = np.nan

            try:
                jobIndustryText = driver.find_element_by_xpath("//div[@id='CompanyContainer']//div[@class='d-flex flex-wrap']/div[4]/span[@class='css-i9gxme e1pvx6aw2']").text
            except Exception:
                jobIndustryText = np.nan

            try:
                jobSectorText = driver.find_element_by_xpath("//div[@id='CompanyContainer']//div[@class='d-flex flex-wrap']/div[5]/span[@class='css-i9gxme e1pvx6aw2']").text
            except Exception:
                jobSectorText = np.nan

            try:
                companyRevenueText = driver.find_element_by_xpath("//div[@id='CompanyContainer']//div[@class='d-flex flex-wrap']/div[6]/span[@class='css-i9gxme e1pvx6aw2']").text
            except Exception:
                companyRevenueText = np.nan

            try:
                jobSalaryText = driver.find_element_by_xpath("//span[contains(@class, 'css-56kyx5 css-16kxj2j e1wijj242')]").text
            except Exception:
                jobSalaryText = np.nan

            # Title, company name and job location are directly available so for each job it's corresponding values are assigned
            
            try:
                driver.set_page_load_timeout(30)
                jobTitleText = jobTitles[i].text
            except Exception:
                jobTitleText = np.nan
                    
            
            try:
                driver.set_page_load_timeout(30)
                companyNameText = companyNames[i].text
            except Exception:
                companyNameText = np.nan
                
            try:
                driver.set_page_load_timeout(30)
                jobLocationText = jobLocations[i].text
            except Exception:
                jobLocationText = np.nan

            # Storing all the data into dataset
            data = data.append({'Job Title': jobTitleText, 'Salary Estimate': jobSalaryText, 'Job Description': jobDescriptionText, 'Rating': jobRatingText, 'Company Name': companyNameText, 
                                     'Location': jobLocationText, 'Size': emplooyeSizeText, 'Founded': companyFoundedText, 'Type of Ownership': companyTypeText, 'Industry': jobIndustryText, 
                                     'Sector': jobSectorText, 'Revenue': companyRevenueText},  ignore_index = True)

            data.to_csv('Data_science_jobs.csv')
        driver.set_page_load_timeout(30)
        driver.find_element_by_xpath("//a[@data-test='pagination-next']//span[@class='SVGInline']").click()
        
        time.sleep(3)
       



    driver.quit()
    
    return data

# %%
get_jobs('data scientist',  6, requiredCountryData = "India")
# Out:
#     Founded              Size     Location Type of Ownership         Sector  \
# 0      1967  10000+ Employees    Bangalore  Company - Public  Manufacturing
# 1      1967  10000+ Employees    Hyderābād  Company - Public  Manufacturing
# 2      1967  10000+ Employees         Pune  Company - Public  Manufacturing
# 3      1967  10000+ Employees       Remote  Company - Public  Manufacturing
# 4      1967  10000+ Employees    Bangalore  Company - Public  Manufacturing
# 5      1967  10000+ Employees         Pune  Company - Public  Manufacturing
# 6      1967  10000+ Employees         Pune  Company - Public  Manufacturing
# 7      1967  10000+ Employees         Pune  Company - Public  Manufacturing
# 8      1967  10000+ Employees      Gurgaon  Company - Public  Manufacturing
# 9      1967  10000+ Employees         Pune  Company - Public  Manufacturing
# 10     1967  10000+ Employees         Pune  Company - Public  Manufacturing
# 11     1967  10000+ Employees         Pune  Company - Public  Manufacturing
# 12     1967  10000+ Employees        India  Company - Public  Manufacturing
# 13     1967  10000+ Employees        India  Company - Public  Manufacturing
# 14     1967  10000+ Employees         Pune  Company - Public  Manufacturing
# 15     1967  10000+ Employees         Pune  Company - Public  Manufacturing
# 16     1967  10000+ Employees     Vadodara  Company - Public  Manufacturing
# 17     1967  10000+ Employees         Pune  Company - Public  Manufacturing
# 18     1967  10000+ Employees         Pune  Company - Public  Manufacturing
# 19     1967  10000+ Employees         Pune  Company - Public  Manufacturing
# 20     1967  10000+ Employees         Pune  Company - Public  Manufacturing
# 21     1967  10000+ Employees         Pune  Company - Public  Manufacturing
# 22     1967  10000+ Employees         Pune  Company - Public  Manufacturing
# 23     1967  10000+ Employees         Pune  Company - Public  Manufacturing
# 24     1967  10000+ Employees        India  Company - Public  Manufacturing
# 25     1967  10000+ Employees      Gurgaon  Company - Public  Manufacturing
# 26     1967  10000+ Employees         Pune  Company - Public  Manufacturing
# 27     1967  10000+ Employees         Pune  Company - Public  Manufacturing
# 28     1967  10000+ Employees         Pune  Company - Public  Manufacturing
# 29     1967  10000+ Employees        Noida  Company - Public  Manufacturing
# 30      NaN               NaN         Pune               NaN            NaN
# 31      NaN               NaN         Pune               NaN            NaN
# 32      NaN               NaN       Mumbai               NaN            NaN
# 33      NaN               NaN         Pune               NaN            NaN
# 34      NaN               NaN         Pune               NaN            NaN
# 35      NaN               NaN       Mumbai               NaN            NaN
# 36      NaN               NaN         Pune               NaN            NaN
# 37      NaN               NaN      Chennai               NaN            NaN
# 38      NaN               NaN         Pune               NaN            NaN
# 39      NaN               NaN         Pune               NaN            NaN
# 40      NaN               NaN         Pune               NaN            NaN
# 41      NaN               NaN    Bangalore               NaN            NaN
# 42      NaN               NaN        India               NaN            NaN
# 43      NaN               NaN         Pune               NaN            NaN
# 44      NaN               NaN       Mumbai               NaN            NaN
# 45      NaN               NaN    Bangalore               NaN            NaN
# 46      NaN               NaN     Vadodara               NaN            NaN
# 47      NaN               NaN       Remote               NaN            NaN
# 48      NaN               NaN  Maharashtra               NaN            NaN
# 49      NaN               NaN         Pune               NaN            NaN
# 50      NaN               NaN         Pune               NaN            NaN
# 51      NaN               NaN         Pune               NaN            NaN
# 52      NaN               NaN       Jaipur               NaN            NaN
# 53      NaN               NaN    Hyderābād               NaN            NaN
# 54      NaN               NaN    Bangalore               NaN            NaN
# 55      NaN               NaN    Bangalore               NaN            NaN
# 56      NaN               NaN         Pune               NaN            NaN
# 57      NaN               NaN         Pune               NaN            NaN
# 58      NaN               NaN         Pune               NaN            NaN
# 59      NaN               NaN        India               NaN            NaN
# 60      NaN               NaN    Bangalore               NaN            NaN
# 61      NaN               NaN    Bangalore               NaN            NaN
# 62      NaN               NaN         Pune               NaN            NaN
# 63      NaN               NaN         Pune               NaN            NaN
# 64      NaN               NaN         Pune               NaN            NaN
# 65      NaN               NaN                            NaN            NaN
# 66     1843  10000+ Employees         Pune  Company - Public  Manufacturing
# 67     1843  10000+ Employees         Pune  Company - Public  Manufacturing
# 68     1843  10000+ Employees         Pune  Company - Public  Manufacturing
# 69     1843  10000+ Employees       Remote  Company - Public  Manufacturing
# 70     1843  10000+ Employees    Bangalore  Company - Public  Manufacturing
# 71     1843  10000+ Employees       Mumbai  Company - Public  Manufacturing
# 72     1843  10000+ Employees       Mumbai  Company - Public  Manufacturing
# 73     1843  10000+ Employees    Bangalore  Company - Public  Manufacturing
# 74     1843  10000+ Employees      Gurgaon  Company - Public  Manufacturing
# 75     1843  10000+ Employees       Remote  Company - Public  Manufacturing
# 76     1843  10000+ Employees    Bangalore  Company - Public  Manufacturing
# 77     1843  10000+ Employees    Bangalore  Company - Public  Manufacturing
# 78     1843  10000+ Employees    Bangalore  Company - Public  Manufacturing
# 79     1843  10000+ Employees         Pune  Company - Public  Manufacturing
# 80     1843  10000+ Employees         Pune  Company - Public  Manufacturing
# 81     1843  10000+ Employees    New Delhi  Company - Public  Manufacturing
# 82     1843  10000+ Employees         Pune  Company - Public  Manufacturing
# 83     1843  10000+ Employees         Pune  Company - Public  Manufacturing
# 84     1843  10000+ Employees    Bangalore  Company - Public  Manufacturing
# 85     1843  10000+ Employees    Bangalore  Company - Public  Manufacturing
# 86     1843  10000+ Employees    Hyderābād  Company - Public  Manufacturing
# 87     1843  10000+ Employees         Pune  Company - Public  Manufacturing
# 88     1843  10000+ Employees    Bangalore  Company - Public  Manufacturing
# 89     1843  10000+ Employees       Remote  Company - Public  Manufacturing
# 90      NaN               NaN       Mumbai               NaN            NaN
# 91      NaN               NaN        India               NaN            NaN
# 92      NaN               NaN    Bangalore               NaN            NaN
# 93      NaN               NaN    Bangalore               NaN            NaN
# 94      NaN               NaN    Bangalore               NaN            NaN
# 95      NaN               NaN    Hyderābād               NaN            NaN
# 96      NaN               NaN    Bangalore               NaN            NaN
# 97      NaN               NaN        India               NaN            NaN
# 98      NaN               NaN        India               NaN            NaN
# 99      NaN               NaN    Bangalore               NaN            NaN
# 100     NaN               NaN         Pune               NaN            NaN
# 101     NaN               NaN    New Delhi               NaN            NaN
# 102     NaN               NaN    Bangalore               NaN            NaN
# 103     NaN               NaN    Bangalore               NaN            NaN
# 104     NaN               NaN    Karnataka               NaN            NaN
# 105     NaN               NaN    Bangalore               NaN            NaN
# 106     NaN               NaN    Bangalore               NaN            NaN
# 107     NaN               NaN    Hyderābād               NaN            NaN
# 108     NaN               NaN    Bangalore               NaN            NaN
# 109     NaN               NaN         Pune               NaN            NaN
# 110     NaN               NaN    Bangalore               NaN            NaN
# 111     NaN               NaN    Bangalore               NaN            NaN
# 112     NaN               NaN        India               NaN            NaN
# 113     NaN               NaN    Bangalore               NaN            NaN
# 114     NaN               NaN    Bangalore               NaN            NaN
# 115     NaN               NaN    Bangalore               NaN            NaN
# 116     NaN               NaN    Bangalore               NaN            NaN
# 117     NaN               NaN       Bhopal               NaN            NaN
# 118     NaN               NaN    Bangalore               NaN            NaN
# 119     NaN               NaN    Bangalore               NaN            NaN
# 120     NaN               NaN       Mumbai               NaN            NaN
# 121     NaN               NaN        India               NaN            NaN
# 122     NaN               NaN    Bangalore               NaN            NaN
# 123     NaN               NaN    Bangalore               NaN            NaN
# 124     NaN               NaN                            NaN            NaN
# 125     NaN               NaN    Bangalore               NaN            NaN
# 126     NaN               NaN        India               NaN            NaN
# 127     NaN               NaN    Bangalore               NaN            NaN
# 128     NaN               NaN         Pune               NaN            NaN
# 129     NaN               NaN    New Delhi               NaN            NaN
# 130     NaN               NaN    Bangalore               NaN            NaN
# 131     NaN               NaN    Karnataka               NaN            NaN
# 132     NaN               NaN    Bangalore               NaN            NaN
# 133     NaN               NaN         Pune               NaN            NaN
# 134     NaN               NaN    Bangalore               NaN            NaN
# 135     NaN               NaN    Bangalore               NaN            NaN
# 136     NaN               NaN    Bangalore               NaN            NaN
# 137     NaN               NaN    Bangalore               NaN            NaN
# 138     NaN               NaN    Bangalore               NaN            NaN
# 139     NaN               NaN    Bangalore               NaN            NaN
# 140     NaN               NaN       Bhopal               NaN            NaN
# 141     NaN               NaN    Bangalore               NaN            NaN
# 142     NaN               NaN    Bangalore               NaN            NaN
# 143     NaN               NaN    Bangalore               NaN            NaN
# 144     NaN               NaN         Pune               NaN            NaN
# 145     NaN               NaN    Bangalore               NaN            NaN
# 146     NaN               NaN    Bangalore               NaN            NaN
# 147     NaN               NaN        India               NaN            NaN
# 148     NaN               NaN    Bangalore               NaN            NaN
# 149     NaN               NaN    Bangalore               NaN            NaN
# 150     NaN               NaN       Mumbai               NaN            NaN
# 151     NaN               NaN    Hyderābād               NaN            NaN
# 152     NaN               NaN    Bangalore               NaN            NaN
# 153     NaN               NaN        India               NaN            NaN
# 154     NaN               NaN    Bangalore               NaN            NaN
# 155     NaN               NaN         Pune               NaN            NaN
# 156     NaN               NaN    New Delhi               NaN            NaN
# 157     NaN               NaN    Bangalore               NaN            NaN
# 158     NaN               NaN    Karnataka               NaN            NaN
# 159     NaN               NaN    Bangalore               NaN            NaN
# 160     NaN               NaN         Pune               NaN            NaN
# 161     NaN               NaN    Bangalore               NaN            NaN
# 162     NaN               NaN    Bangalore               NaN            NaN
# 163     NaN               NaN    Bangalore               NaN            NaN
# 164     NaN               NaN    Bangalore               NaN            NaN
# 165     NaN               NaN    Bangalore               NaN            NaN
# 166     NaN               NaN    Bangalore               NaN            NaN
# 167     NaN               NaN    Bangalore               NaN            NaN
# 168     NaN               NaN         Pune               NaN            NaN
# 169     NaN               NaN    Bangalore               NaN            NaN
# 170     NaN               NaN    Bangalore               NaN            NaN
# 171     NaN               NaN    Bangalore               NaN            NaN
# 172     NaN               NaN    Bangalore               NaN            NaN
# 173     NaN               NaN      Gurgaon               NaN            NaN
# 174     NaN               NaN    Bangalore               NaN            NaN
# 175     NaN               NaN    Bangalore               NaN            NaN
# 176     NaN               NaN    Bangalore               NaN            NaN
# 177     NaN               NaN    Bangalore               NaN            NaN
# 178     NaN               NaN    Bangalore               NaN            NaN
# 179     NaN               NaN    Bangalore               NaN            NaN
#
#                 Revenue Rating                Salary Estimate  \
# 0    $10+ billion (USD)    4.0                            NaN
# 1    $10+ billion (USD)    4.0                            NaN
# 2    $10+ billion (USD)    4.0                            NaN
# 3    $10+ billion (USD)    4.0                            NaN
# 4    $10+ billion (USD)    4.0                            NaN
# 5    $10+ billion (USD)    4.0                            NaN
# 6    $10+ billion (USD)    4.0                            NaN
# 7    $10+ billion (USD)    4.0                            NaN
# 8    $10+ billion (USD)    4.0                            NaN
# 9    $10+ billion (USD)    4.0                            NaN
# 10   $10+ billion (USD)    4.0                            NaN
# 11   $10+ billion (USD)    4.0                            NaN
# 12   $10+ billion (USD)    4.0                            NaN
# 13   $10+ billion (USD)    4.0                            NaN
# 14   $10+ billion (USD)    4.0                            NaN
# 15   $10+ billion (USD)    4.0                            NaN
# 16   $10+ billion (USD)    4.0                            NaN
# 17   $10+ billion (USD)    4.0                            NaN
# 18   $10+ billion (USD)    4.0                            NaN
# 19   $10+ billion (USD)    4.0                            NaN
# 20   $10+ billion (USD)    4.0                            NaN
# 21   $10+ billion (USD)    4.0                            NaN
# 22   $10+ billion (USD)    4.0                            NaN
# 23   $10+ billion (USD)    4.0                            NaN
# 24   $10+ billion (USD)    4.0                            NaN
# 25   $10+ billion (USD)    4.0                            NaN
# 26   $10+ billion (USD)    4.0                            NaN
# 27   $10+ billion (USD)    4.0                            NaN
# 28   $10+ billion (USD)    4.0                            NaN
# 29   $10+ billion (USD)    4.0                            NaN
# 30                  NaN    NaN          ₹223K (Employer est.)
# 31                  NaN    NaN          ₹223K (Employer est.)
# 32                  NaN    NaN          ₹223K (Employer est.)
# 33                  NaN    NaN          ₹223K (Employer est.)
# 34                  NaN    NaN          ₹223K (Employer est.)
# 35                  NaN    NaN          ₹223K (Employer est.)
# 36                  NaN    NaN          ₹223K (Employer est.)
# 37                  NaN    NaN          ₹223K (Employer est.)
# 38                  NaN    NaN          ₹223K (Employer est.)
# 39                  NaN    NaN          ₹223K (Employer est.)
# 40                  NaN    NaN          ₹223K (Employer est.)
# 41                  NaN    NaN          ₹223K (Employer est.)
# 42                  NaN    NaN          ₹223K (Employer est.)
# 43                  NaN    NaN          ₹223K (Employer est.)
# 44                  NaN    NaN          ₹223K (Employer est.)
# 45                  NaN    NaN          ₹223K (Employer est.)
# 46                  NaN    NaN          ₹223K (Employer est.)
# 47                  NaN    NaN          ₹223K (Employer est.)
# 48                  NaN    NaN          ₹223K (Employer est.)
# 49                  NaN    NaN          ₹223K (Employer est.)
# 50                  NaN    NaN          ₹223K (Employer est.)
# 51                  NaN    NaN          ₹223K (Employer est.)
# 52                  NaN    NaN          ₹223K (Employer est.)
# 53                  NaN    NaN          ₹223K (Employer est.)
# 54                  NaN    NaN          ₹223K (Employer est.)
# 55                  NaN    NaN          ₹223K (Employer est.)
# 56                  NaN    NaN          ₹223K (Employer est.)
# 57                  NaN    NaN          ₹223K (Employer est.)
# 58                  NaN    NaN          ₹223K (Employer est.)
# 59                  NaN    NaN          ₹223K (Employer est.)
# 60                  NaN    NaN  ₹180K - ₹360K (Employer est.)
# 61                  NaN    NaN  ₹180K - ₹360K (Employer est.)
# 62                  NaN    NaN  ₹180K - ₹360K (Employer est.)
# 63                  NaN    NaN  ₹180K - ₹360K (Employer est.)
# 64                  NaN    NaN  ₹180K - ₹360K (Employer est.)
# 65                  NaN    NaN  ₹180K - ₹360K (Employer est.)
# 66   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 67   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 68   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 69   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 70   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 71   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 72   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 73   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 74   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 75   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 76   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 77   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 78   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 79   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 80   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 81   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 82   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 83   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 84   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 85   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 86   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 87   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 88   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 89   $10+ billion (USD)    4.1  ₹180K - ₹360K (Employer est.)
# 90                  NaN    NaN    ₹500K - ₹1M (Employer est.)
# 91                  NaN    NaN    ₹500K - ₹1M (Employer est.)
# 92                  NaN    NaN    ₹500K - ₹1M (Employer est.)
# 93                  NaN    NaN    ₹500K - ₹1M (Employer est.)
# 94                  NaN    NaN    ₹500K - ₹1M (Employer est.)
# 95                  NaN    NaN    ₹500K - ₹1M (Employer est.)
# 96                  NaN    NaN    ₹500K - ₹1M (Employer est.)
# 97                  NaN    NaN    ₹500K - ₹1M (Employer est.)
# 98                  NaN    NaN    ₹500K - ₹1M (Employer est.)
# 99                  NaN    NaN    ₹500K - ₹1M (Employer est.)
# 100                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 101                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 102                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 103                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 104                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 105                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 106                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 107                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 108                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 109                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 110                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 111                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 112                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 113                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 114                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 115                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 116                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 117                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 118                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 119                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 120                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 121                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 122                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 123                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 124                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 125                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 126                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 127                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 128                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 129                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 130                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 131                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 132                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 133                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 134                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 135                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 136                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 137                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 138                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 139                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 140                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 141                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 142                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 143                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 144                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 145                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 146                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 147                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 148                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 149                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 150                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 151                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 152                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 153                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 154                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 155                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 156                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 157                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 158                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 159                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 160                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 161                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 162                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 163                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 164                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 165                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 166                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 167                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 168                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 169                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 170                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 171                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 172                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 173                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 174                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 175                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 176                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 177                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 178                 NaN    NaN    ₹500K - ₹1M (Employer est.)
# 179                 NaN    NaN    ₹500K - ₹1M (Employer est.)
#
#                                              Job Title  \
# 0                                       Data Scientist
# 1                              Product: Data Scientist
# 2                                     Data Scientist I
# 3                                Senior Data Scientist
# 4                                       Data Scientist
# 5                             Associate Data Scientist
# 6                                       Data Scientist
# 7                 Data Scientist R Python Google Cloud
# 8                                       Data Scientist
# 9                Machine learning and Python Developer
# 10                                Prin, Data Scientist
# 11                                 Data Science Intern
# 12                                Data Scientist (m/f)
# 13                               Data Scientist Intern
# 14                                        Data Science
# 15                                      Data Scientist
# 16                                      Data Scientist
# 17                            Data Scientist Jr. & Sr.
# 18                                      Data Scientist
# 19                                      Data Scientist
# 20              Big Data and Machine Learning Engineer
# 21                                      Data Scientist
# 22                                 Data Science Intern
# 23                           Data Scientist(6-9 Years)
# 24               Data Scientist Internship Opportunity
# 25                                      Data Scientist
# 26                                      Data Scientist
# 27                                      Data Scientist
# 28        AI / ML / Data Engr -Analyst-Scientist / IOT
# 29                            Associate Data Scientist
# 30                                      Data Scientist
# 31                            Associate Data Scientist
# 32       Data Scientist Associate - Wholesale Payments
# 33                                      Data Scientist
# 34                           Specialist Data Scientist
# 35
# 36                                      Data Scientist
# 37                 Associate Data Scientist (Upstream)
# 38                                      Data Scientist
# 39                                      Data Scientist
# 40          Data Scientist( Statistics Specialization)
# 41      Natural Language Processing Engineer/Scientist
# 42                                      Data Scientist
# 43                                  Sr. Data Scientist
# 44                             Scientist, Data Science
# 45             Data Scientist - (New Grad) - India UHR
# 46                          Executive - Data Scientist
# 47                                      Data Scientist
# 48                                      Data Scientist
# 49                        Data Scientist - Innovations
# 50                                   Sr Data Scientist
# 51                                   Data Scientist_TS
# 52                                      Data Scientist
# 53                              Intern, Data Scientist
# 54                           RD I/TBT - data scientist
# 55                   Data Scientist / BigData Engineer
# 56          Data Scientist / Machine Learning Engineer
# 57                                      Data Scientist
# 58                        Data Scientist - Innovations
# 59                                Sr. Data Scientist-I
# 60                        Sr Data Scientist (Level 10)
# 61                                      Data Scientist
# 62                                   Sr Data Scientist
# 63                               Senior Data Scientist
# 64                       Scientist (Applied Mechanics)
# 65                              Data Scientist (m/f/d)
# 66                      Data Scientist II - APAC-based
# 67                      Sr. Data Scientist - R, Python
# 68                                      Data Scientist
# 69                            Pre-sales Data Scientist
# 70       Junior Data Scientist / Data Analyst (Remote)
# 71                                      Data Scientist
# 72                           Data Scientist Consultant
# 73                                      Data Scientist
# 74                            Analyst - Data Scientist
# 75                                      Data Scientist
# 76                          Data Scientist (Technical)
# 77                                      Data Scientist
# 78                                   Data Scientist II
# 79                  Machine Learning Engineer - Intern
# 80                                      Data Scientist
# 81                                      Data Scientist
# 82           Data Scientist – Smart Building Analytics
# 83                                      Data Scientist
# 84   Data Analytics part time job/internship at Ban...
# 85          Data Scientist - (Intern) - India /SCO UHR
# 86                               Data Scientist Intern
# 87                               Senior Data Scientist
# 88                              Data Scientist - Sales
# 89                                      Data Scientist
# 90                           Machine Learning Engineer
# 91                                Deep Learning Intern
# 92                 Machine Learning Engineer - Interns
# 93                           Python & Machine Learning
# 94                         Decision Scientist - GoFood
# 95    Cybersecurity, AI and Machine Learning Engineers
# 96                                       Engineer - AI
# 97                       Jr. Data Science Professional
# 98                                      Data Scientist
# 99                   Research Engineer I -Data Science
# 100                            Python Machine Learning
# 101                                 Jr. AI/ML Engineer
# 102                                     Data Scientist
# 103                                     Data Scientist
# 104                               Data Scientist-India
# 105                                  Applied Scientist
# 106                                     Data Scientist
# 107                                     Data Scientist
# 108                                     Data Scientist
# 109                 Analyst Data Science and Analytics
# 110                       Specialist II - Data Science
# 111                                     Data Scientist
# 112                                     Data Scientist
# 113                                 Sr. Data Scientist
# 114                          Machine Learning Engineer
# 115                                     Data Scientist
# 116                          Data Analytics Internship
# 117                                     Data Scientist
# 118                                     Data Scientist
# 119                                     Data Scientist
# 120                          Machine Learning Engineer
# 121                               Deep Learning Intern
# 122                Machine Learning Engineer - Interns
# 123                          Python & Machine Learning
# 124   Cybersecurity, AI and Machine Learning Engineers
# 125                                      Engineer - AI
# 126                      Jr. Data Science Professional
# 127                  Research Engineer I -Data Science
# 128                            Python Machine Learning
# 129                                 Jr. AI/ML Engineer
# 130                                     Data Scientist
# 131                               Data Scientist-India
# 132                                  Applied Scientist
# 133                 Analyst Data Science and Analytics
# 134                       Specialist II - Data Science
# 135                                     Data Scientist
# 136                                 Sr. Data Scientist
# 137                          Machine Learning Engineer
# 138                                     Data Scientist
# 139                          Data Analytics Internship
# 140                                     Data Scientist
# 141                                     Data Scientist
# 142                 Senior Programmer - Data Scientist
# 143                                   Data Scientist 2
# 144  Openings for Machine Learning Candidates with ...
# 145                        Data Scientist, Engineering
# 146                                     Data Scientist
# 147                           Data Scientist Jendamark
# 148                           EBP AI/ML Data Scientist
# 149                            Data Science Internship
# 150                          Machine Learning Engineer
# 151   Cybersecurity, AI and Machine Learning Engineers
# 152                                      Engineer - AI
# 153                      Jr. Data Science Professional
# 154                  Research Engineer I -Data Science
# 155                            Python Machine Learning
# 156                                 Jr. AI/ML Engineer
# 157                                     Data Scientist
# 158                               Data Scientist-India
# 159                                  Applied Scientist
# 160                 Analyst Data Science and Analytics
# 161                       Specialist II - Data Science
# 162                          Machine Learning Engineer
# 163                                     Data Scientist
# 164                          Data Analytics Internship
# 165                                     Data Scientist
# 166                 Senior Programmer - Data Scientist
# 167                                   Data Scientist 2
# 168  Openings for Machine Learning Candidates with ...
# 169                        Data Scientist, Engineering
# 170                                     Data Scientist
# 171                           EBP AI/ML Data Scientist
# 172                            Data Science Internship
# 173                                     Data Scientist
# 174                Associate, Data Science & Analytics
# 175                     ENGINEER - AI/MACHINE-LEARNING
# 176                     Data Scientist II - APAC-based
# 177                                     Data Scientist
# 178                                     Data Scientist
# 179  Artificial Intelligence & Machine Learning Exp...
#
#                                        Job Description  \
# 0    Job Expectations\nThe Data Scientist job expec...
# 1    Job Expectations\nThe Data Scientist job expec...
# 2    Job Expectations\nThe Data Scientist job expec...
# 3    Job Expectations\nThe Data Scientist job expec...
# 4    Job Expectations\nThe Data Scientist job expec...
# 5    Job Expectations\nThe Data Scientist job expec...
# 6    Job Expectations\nThe Data Scientist job expec...
# 7    Job Expectations\nThe Data Scientist job expec...
# 8    Job Expectations\nThe Data Scientist job expec...
# 9    Job Expectations\nThe Data Scientist job expec...
# 10   Job Expectations\nThe Data Scientist job expec...
# 11   Job Expectations\nThe Data Scientist job expec...
# 12   Job Expectations\nThe Data Scientist job expec...
# 13   Job Expectations\nThe Data Scientist job expec...
# 14   Job Expectations\nThe Data Scientist job expec...
# 15   Job Expectations\nThe Data Scientist job expec...
# 16   Job Expectations\nThe Data Scientist job expec...
# 17   Job Expectations\nThe Data Scientist job expec...
# 18   Job Expectations\nThe Data Scientist job expec...
# 19   Job Expectations\nThe Data Scientist job expec...
# 20   Job Expectations\nThe Data Scientist job expec...
# 21   Job Expectations\nThe Data Scientist job expec...
# 22   Job Expectations\nThe Data Scientist job expec...
# 23   Job Expectations\nThe Data Scientist job expec...
# 24   Job Expectations\nThe Data Scientist job expec...
# 25   Job Expectations\nThe Data Scientist job expec...
# 26   Job Expectations\nThe Data Scientist job expec...
# 27   Job Expectations\nThe Data Scientist job expec...
# 28   Job Expectations\nThe Data Scientist job expec...
# 29   Job Expectations\nThe Data Scientist job expec...
# 30   Responsibilities for Data Scientist/ NLP Engin...
# 31   Responsibilities for Data Scientist/ NLP Engin...
# 32   Responsibilities for Data Scientist/ NLP Engin...
# 33   Responsibilities for Data Scientist/ NLP Engin...
# 34   Responsibilities for Data Scientist/ NLP Engin...
# 35   Responsibilities for Data Scientist/ NLP Engin...
# 36   Responsibilities for Data Scientist/ NLP Engin...
# 37   Responsibilities for Data Scientist/ NLP Engin...
# 38   Responsibilities for Data Scientist/ NLP Engin...
# 39   Responsibilities for Data Scientist/ NLP Engin...
# 40   Responsibilities for Data Scientist/ NLP Engin...
# 41   Responsibilities for Data Scientist/ NLP Engin...
# 42   Responsibilities for Data Scientist/ NLP Engin...
# 43   Responsibilities for Data Scientist/ NLP Engin...
# 44   Responsibilities for Data Scientist/ NLP Engin...
# 45   Responsibilities for Data Scientist/ NLP Engin...
# 46   Responsibilities for Data Scientist/ NLP Engin...
# 47   Responsibilities for Data Scientist/ NLP Engin...
# 48   Responsibilities for Data Scientist/ NLP Engin...
# 49   Responsibilities for Data Scientist/ NLP Engin...
# 50   Responsibilities for Data Scientist/ NLP Engin...
# 51   Responsibilities for Data Scientist/ NLP Engin...
# 52   Responsibilities for Data Scientist/ NLP Engin...
# 53   Responsibilities for Data Scientist/ NLP Engin...
# 54   Responsibilities for Data Scientist/ NLP Engin...
# 55   Responsibilities for Data Scientist/ NLP Engin...
# 56   Responsibilities for Data Scientist/ NLP Engin...
# 57   Responsibilities for Data Scientist/ NLP Engin...
# 58   Responsibilities for Data Scientist/ NLP Engin...
# 59   Responsibilities for Data Scientist/ NLP Engin...
# 60   Responsibilities for Data Scientist/ NLP Engin...
# 61   Responsibilities for Data Scientist/ NLP Engin...
# 62   Responsibilities for Data Scientist/ NLP Engin...
# 63   Responsibilities for Data Scientist/ NLP Engin...
# 64   Responsibilities for Data Scientist/ NLP Engin...
# 65   Responsibilities for Data Scientist/ NLP Engin...
# 66   Responsibilities for Data Scientist/ NLP Engin...
# 67   Senior Data Scientist\nSiemens founded the new...
# 68   Senior Data Scientist\nSiemens founded the new...
# 69   Senior Data Scientist\nSiemens founded the new...
# 70   Senior Data Scientist\nSiemens founded the new...
# 71   Senior Data Scientist\nSiemens founded the new...
# 72   Senior Data Scientist\nSiemens founded the new...
# 73   Senior Data Scientist\nSiemens founded the new...
# 74   Senior Data Scientist\nSiemens founded the new...
# 75   Senior Data Scientist\nSiemens founded the new...
# 76   Senior Data Scientist\nSiemens founded the new...
# 77   Senior Data Scientist\nSiemens founded the new...
# 78   Senior Data Scientist\nSiemens founded the new...
# 79   Senior Data Scientist\nSiemens founded the new...
# 80   Senior Data Scientist\nSiemens founded the new...
# 81   Senior Data Scientist\nSiemens founded the new...
# 82   Senior Data Scientist\nSiemens founded the new...
# 83   Senior Data Scientist\nSiemens founded the new...
# 84   Senior Data Scientist\nSiemens founded the new...
# 85   Senior Data Scientist\nSiemens founded the new...
# 86   Senior Data Scientist\nSiemens founded the new...
# 87   Senior Data Scientist\nSiemens founded the new...
# 88   Senior Data Scientist\nSiemens founded the new...
# 89   Senior Data Scientist\nSiemens founded the new...
# 90   Experience: 2 - 4 years\nSkills Required:\nMac...
# 91   Experience: 2 - 4 years\nSkills Required:\nMac...
# 92   Experience: 2 - 4 years\nSkills Required:\nMac...
# 93   Experience: 2 - 4 years\nSkills Required:\nMac...
# 94   Experience: 2 - 4 years\nSkills Required:\nMac...
# 95   Experience: 2 - 4 years\nSkills Required:\nMac...
# 96   Experience: 2 - 4 years\nSkills Required:\nMac...
# 97   Experience: 2 - 4 years\nSkills Required:\nMac...
# 98   Experience: 2 - 4 years\nSkills Required:\nMac...
# 99   Experience: 2 - 4 years\nSkills Required:\nMac...
# 100  Experience: 2 - 4 years\nSkills Required:\nMac...
# 101  Experience: 2 - 4 years\nSkills Required:\nMac...
# 102  Experience: 2 - 4 years\nSkills Required:\nMac...
# 103  Experience: 2 - 4 years\nSkills Required:\nMac...
# 104  Experience: 2 - 4 years\nSkills Required:\nMac...
# 105  Experience: 2 - 4 years\nSkills Required:\nMac...
# 106  Experience: 2 - 4 years\nSkills Required:\nMac...
# 107  Experience: 2 - 4 years\nSkills Required:\nMac...
# 108  Experience: 2 - 4 years\nSkills Required:\nMac...
# 109  Experience: 2 - 4 years\nSkills Required:\nMac...
# 110  Experience: 2 - 4 years\nSkills Required:\nMac...
# 111  Experience: 2 - 4 years\nSkills Required:\nMac...
# 112  Experience: 2 - 4 years\nSkills Required:\nMac...
# 113  Experience: 2 - 4 years\nSkills Required:\nMac...
# 114  Experience: 2 - 4 years\nSkills Required:\nMac...
# 115  Experience: 2 - 4 years\nSkills Required:\nMac...
# 116  Experience: 2 - 4 years\nSkills Required:\nMac...
# 117  Experience: 2 - 4 years\nSkills Required:\nMac...
# 118  Experience: 2 - 4 years\nSkills Required:\nMac...
# 119  Experience: 2 - 4 years\nSkills Required:\nMac...
# 120  Experience: 2 - 4 years\nSkills Required:\nMac...
# 121  Experience: 2 - 4 years\nSkills Required:\nMac...
# 122  Experience: 2 - 4 years\nSkills Required:\nMac...
# 123  Experience: 2 - 4 years\nSkills Required:\nMac...
# 124  Experience: 2 - 4 years\nSkills Required:\nMac...
# 125  Experience: 2 - 4 years\nSkills Required:\nMac...
# 126  Experience: 2 - 4 years\nSkills Required:\nMac...
# 127  Experience: 2 - 4 years\nSkills Required:\nMac...
# 128  Experience: 2 - 4 years\nSkills Required:\nMac...
# 129  Experience: 2 - 4 years\nSkills Required:\nMac...
# 130  Experience: 2 - 4 years\nSkills Required:\nMac...
# 131  Experience: 2 - 4 years\nSkills Required:\nMac...
# 132  Experience: 2 - 4 years\nSkills Required:\nMac...
# 133  Experience: 2 - 4 years\nSkills Required:\nMac...
# 134  Experience: 2 - 4 years\nSkills Required:\nMac...
# 135  Experience: 2 - 4 years\nSkills Required:\nMac...
# 136  Experience: 2 - 4 years\nSkills Required:\nMac...
# 137  Experience: 2 - 4 years\nSkills Required:\nMac...
# 138  Experience: 2 - 4 years\nSkills Required:\nMac...
# 139  Experience: 2 - 4 years\nSkills Required:\nMac...
# 140  Experience: 2 - 4 years\nSkills Required:\nMac...
# 141  Experience: 2 - 4 years\nSkills Required:\nMac...
# 142  Experience: 2 - 4 years\nSkills Required:\nMac...
# 143  Experience: 2 - 4 years\nSkills Required:\nMac...
# 144  Experience: 2 - 4 years\nSkills Required:\nMac...
# 145  Experience: 2 - 4 years\nSkills Required:\nMac...
# 146  Experience: 2 - 4 years\nSkills Required:\nMac...
# 147  Experience: 2 - 4 years\nSkills Required:\nMac...
# 148  Experience: 2 - 4 years\nSkills Required:\nMac...
# 149  Experience: 2 - 4 years\nSkills Required:\nMac...
# 150  Experience: 2 - 4 years\nSkills Required:\nMac...
# 151  Experience: 2 - 4 years\nSkills Required:\nMac...
# 152  Experience: 2 - 4 years\nSkills Required:\nMac...
# 153  Experience: 2 - 4 years\nSkills Required:\nMac...
# 154  Experience: 2 - 4 years\nSkills Required:\nMac...
# 155  Experience: 2 - 4 years\nSkills Required:\nMac...
# 156  Experience: 2 - 4 years\nSkills Required:\nMac...
# 157  Experience: 2 - 4 years\nSkills Required:\nMac...
# 158  Experience: 2 - 4 years\nSkills Required:\nMac...
# 159  Experience: 2 - 4 years\nSkills Required:\nMac...
# 160  Experience: 2 - 4 years\nSkills Required:\nMac...
# 161  Experience: 2 - 4 years\nSkills Required:\nMac...
# 162  Experience: 2 - 4 years\nSkills Required:\nMac...
# 163  Experience: 2 - 4 years\nSkills Required:\nMac...
# 164  Experience: 2 - 4 years\nSkills Required:\nMac...
# 165  Experience: 2 - 4 years\nSkills Required:\nMac...
# 166  Experience: 2 - 4 years\nSkills Required:\nMac...
# 167  Experience: 2 - 4 years\nSkills Required:\nMac...
# 168  Experience: 2 - 4 years\nSkills Required:\nMac...
# 169  Experience: 2 - 4 years\nSkills Required:\nMac...
# 170  Experience: 2 - 4 years\nSkills Required:\nMac...
# 171  Experience: 2 - 4 years\nSkills Required:\nMac...
# 172  Experience: 2 - 4 years\nSkills Required:\nMac...
# 173  Experience: 2 - 4 years\nSkills Required:\nMac...
# 174  Experience: 2 - 4 years\nSkills Required:\nMac...
# 175  Experience: 2 - 4 years\nSkills Required:\nMac...
# 176  Experience: 2 - 4 years\nSkills Required:\nMac...
# 177  Experience: 2 - 4 years\nSkills Required:\nMac...
# 178  Experience: 2 - 4 years\nSkills Required:\nMac...
# 179  Experience: 2 - 4 years\nSkills Required:\nMac...
#
#                                   Industry  \
# 0    Electrical & Electronic Manufacturing
# 1    Electrical & Electronic Manufacturing
# 2    Electrical & Electronic Manufacturing
# 3    Electrical & Electronic Manufacturing
# 4    Electrical & Electronic Manufacturing
# 5    Electrical & Electronic Manufacturing
# 6    Electrical & Electronic Manufacturing
# 7    Electrical & Electronic Manufacturing
# 8    Electrical & Electronic Manufacturing
# 9    Electrical & Electronic Manufacturing
# 10   Electrical & Electronic Manufacturing
# 11   Electrical & Electronic Manufacturing
# 12   Electrical & Electronic Manufacturing
# 13   Electrical & Electronic Manufacturing
# 14   Electrical & Electronic Manufacturing
# 15   Electrical & Electronic Manufacturing
# 16   Electrical & Electronic Manufacturing
# 17   Electrical & Electronic Manufacturing
# 18   Electrical & Electronic Manufacturing
# ...
# 57                                     NaN
# 58                                     NaN
# 59                                     NaN
# 60                                     NaN
# 61                                     NaN
# 62                                     NaN
# 63                                     NaN
# 64                                     NaN
# 65                                     NaN
# 66   Electrical & Electronic Manufacturing
# 67   Electrical & Electronic Manufacturing
# 68   Electrical & Electronic Manufacturing
# 69   Electrical & Electronic Manufacturing
# 70   Electrical & Electronic Manufacturing
# 71   Electrical & Electronic Manufacturing
# 72   Electrical & Electronic Manufacturing
# 73   Electrical & Electronic Manufacturing
# 74   Electrical & Electronic Manufacturing
# 75   Electrical & Electronic Manufacturing
# 76   Electrical & Electronic Manufacturing
# 77   Electrical & Electronic Manufacturing
# 78   Electrical & Electronic Manufacturing
# 79   Electrical & Electronic Manufacturing
# 80   Electrical & Electronic Manufacturing
# 81   Electrical & Electronic Manufacturing
# 82   Electrical & Electronic Manufacturing
# 83   Electrical & Electronic Manufacturing
# 84   Electrical & Electronic Manufacturing
# 85   Electrical & Electronic Manufacturing
# 86   Electrical & Electronic Manufacturing
# 87   Electrical & Electronic Manufacturing
# 88   Electrical & Electronic Manufacturing
# 89   Electrical & Electronic Manufacturing
# 90                                     NaN
# 91                                     NaN
# 92                                     NaN
# 93                                     NaN
# 94                                     NaN
# 95                                     NaN
# 96                                     NaN
# 97                                     NaN
# 98                                     NaN
# 99                                     NaN
# 100                                    NaN
# 101                                    NaN
# 102                                    NaN
# 103                                    NaN
# 104                                    NaN
# 105                                    NaN
# 106                                    NaN
# 107                                    NaN
# 108                                    NaN
# 109                                    NaN
# 110                                    NaN
# 111                                    NaN
# 112                                    NaN
# 113                                    NaN
# 114                                    NaN
# 115                                    NaN
# 116                                    NaN
# 117                                    NaN
# 118                                    NaN
# 119                                    NaN
# 120                                    NaN
# 121                                    NaN
# 122                                    NaN
# 123                                    NaN
# 124                                    NaN
# 125                                    NaN
# 126                                    NaN
# 127                                    NaN
# 128                                    NaN
# 129                                    NaN
# 130                                    NaN
# 131                                    NaN
# 132                                    NaN
# 133                                    NaN
# 134                                    NaN
# 135                                    NaN
# 136                                    NaN
# 137                                    NaN
# 138                                    NaN
# 139                                    NaN
# 140                                    NaN
# 141                                    NaN
# 142                                    NaN
# 143                                    NaN
# 144                                    NaN
# 145                                    NaN
# 146                                    NaN
# 147                                    NaN
# 148                                    NaN
# 149                                    NaN
# 150                                    NaN
# 151                                    NaN
# 152                                    NaN
# 153                                    NaN
# 154                                    NaN
# 155                                    NaN
# 156                                    NaN
# 157                                    NaN
# 158                                    NaN
# 159                                    NaN
# 160                                    NaN
# 161                                    NaN
# 162                                    NaN
# 163                                    NaN
# 164                                    NaN
# 165                                    NaN
# 166                                    NaN
# 167                                    NaN
# 168                                    NaN
# 169                                    NaN
# 170                                    NaN
# 171                                    NaN
# 172                                    NaN
# 173                                    NaN
# 174                                    NaN
# 175                                    NaN
# 176                                    NaN
# 177                                    NaN
# 178                                    NaN
# 179                                    NaN
#
#                                           Company Name
# 0                               Applied Materials Inc.
# 1                                               Indeed
# 2                                           UST Global
# 3                      ParallelDots Technology Pvt Ltd
# 4                                                 Visa
# 5
# 6                                   247 Global Recruit
# 7                                   Freemind Solutions
# 8                                           MasterCard
# 9                                      Infosys Limited
# 10                                          BNY Mellon
# 11                         Uptricks Services Pvt. Ltd.
# 12                                               Brose
# 13                                       OXO Solutions
# 14                                    3RI TECHNOLOGIES
# 15                                  VM3 Tech Solutions
# 16                                           NielsenIQ
# 17                        thyssenkrupp India Pvt. Ltd.
# 18                                     Springer Nature
# 19                       Copernicus Consulting Pvt Ltd
# 20                                                Citi
# 21                                              Maersk
# 22                                     Aera Technology
# 23     Siemens Technology and Services Private Limited
# 24                                           Microsoft
# 25                                             Deciman
# 26                           Shyena Tech Yarns Pvt Ltd
# 27                    Pivotchain Solution Technologies
# 28                                             Calsoft
# 29                Liberin Technologies Private Limited
# 30                                          UTURNGROUP
# 31                                   Yash Technologies
# 32                           JPMorgan Chase Bank, N.A.
# 33                              KPIT Technologies GmbH
# 34                                                NICE
# 35                                          SHL Global
# 36                                                 KBR
# 37                                               Shell
# 38                                              Qualys
# 39                                          Innoplexus
# 40                               ArrayGen Technologies
# 41                                        Interactions
# 42                              Mondelēz International
# 43                                              TomTom
# 44                                       XPO Logistics
# 45                                       Cisco Systems
# 46                                           NielsenIQ
# 47                                           Wise Monk
# 48                                  Aditya Birla Group
# 49                                      Merkle Sokrati
# 50                                      Evolent Health
# 51                                              AppZen
# 52                                   Jumio Corporation
# 53                                   Micron Technology
# 54   Mercedes-Benz Research and Development India P...
# 55                                             Agilite
# 56                                            PubMatic
# 57                                          AlphaSense
# 58                                              Merkle
# 59                                       General Mills
# 60     Siemens Technology and Services Private Limited
# 61                                                 ABB
# 62                                                 IBM
# 63                                             Peak AI
# 64                                             Corning
# 65                                       aioneers GmbH
# 66                                             Agiloft
# 67                                          DataMetica
# 68                                           Frontdoor
# 69                                           DataRobot
# 70                                          KayaDev AI
# 71                    Happy- A Digital Lending Fintech
# 72                                                 SHL
# 73                                      Canum Infotech
# 74                                     United Airlines
# 75                                        Hire Digital
# 76                                            Ericsson
# 77                               Careator Technologies
# 78                                           Honeywell
# 79                                     Aera Technology
# 80                       LiveVectors Solutions Pvt Ltd
# 81                                               WinZO
# 82                                             Siemens
# 83                          Vijaya Management Services
# 84                                              Miurac
# 85                                       Cisco Systems
# 86                           Arthashastra Intelligence
# 87                                              Maersk
# 88                                              Apptio
# 89                                        Digbi Health
# 90                                         Ladderlogiq
# 91                                       OXO Solutions
# 92                                       IceCream Labs
# 93                                     Technology Next
# 94                                              GO-JEK
# 95                                 GITTY Apps Pvt. Ltd
# 96                                        ThoughtFocus
# 97               Harmony Data Integration Technologies
# 98                                      Wolters Kluwer
# 99                                             Philips
# 100                               e-Innosec Consulting
# 101                                        DarioHealth
# 102    Siemens Technology and Services Private Limited
# 103                           Cumulations Technologies
# 104                                      DeliverHealth
# 105                                           Flipkart
# 106                                     Great Learning
# 107                                 GD Research Center
# 108                                  Datanow solutions
# 109                                         TransUnion
# 110                                            Philips
# 111                                              Ganit
# 112                                        TCG Digital
# 113                                          EagleView
# 114                                          Quantiphi
# 115                                   Verisk Financial
# 116                                            Winuall
# 117                                              Xeeva
# 118                                            Niramai
# 119                                             Intuit
# 120                                        Ladderlogiq
# 121                                      OXO Solutions
# 122                                      IceCream Labs
# 123                                    Technology Next
# 124                                GITTY Apps Pvt. Ltd
# 125                                       ThoughtFocus
# 126              Harmony Data Integration Technologies
# 127                                            Philips
# 128                               e-Innosec Consulting
# 129                                        DarioHealth
# 130                           Cumulations Technologies
# 131                                      DeliverHealth
# 132                                           Flipkart
# 133                                         TransUnion
# 134                                            Philips
# 135                                              Ganit
# 136                                          EagleView
# 137                                          Quantiphi
# 138                                   Verisk Financial
# 139                                            Winuall
# 140                                              Xeeva
# 141                                            Niramai
# 142                                                GSK
# 143                                             GO-JEK
# 144                                          Vyom Labs
# 145                                             Google
# 146                                             Metyis
# 147                                          Jendamark
# 148                                                 HP
# 149                                   Retranz Infolabs
# 150                                        Ladderlogiq
# 151                                GITTY Apps Pvt. Ltd
# 152                                       ThoughtFocus
# 153              Harmony Data Integration Technologies
# 154                                            Philips
# 155                               e-Innosec Consulting
# 156                                        DarioHealth
# 157                           Cumulations Technologies
# 158                                      DeliverHealth
# 159                                           Flipkart
# 160                                         TransUnion
# 161                                            Philips
# 162                                          Quantiphi
# 163                                   Verisk Financial
# 164                                            Winuall
# 165                                            Niramai
# 166                                                GSK
# 167                                             GO-JEK
# 168                                          Vyom Labs
# 169                                             Google
# 170                                             Metyis
# 171                                                 HP
# 172                                   Retranz Infolabs
# 173                                Aliqan Technologies
# 174                                  Collins Aerospace
# 175                               Harman International
# 176                                            Agiloft
# 177                                             Skoruz
# 178                                       Polaris Inc.
# 179                                    Infosys Limited
